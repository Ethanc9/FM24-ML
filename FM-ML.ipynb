# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Load the CSV file into a pandas DataFrame
df = pd.read_csv('player-attributes.csv')

# %%
# List of columns you want to exclude from training
columns_to_exclude = ['Unnamed: 0', 'Name','Age', 'Club', 'Division', 'Based', 'Nation', 'Height', 'Weight', 'Preferred Foot', 'Value', 'Wage', 'PA']

# Drop the columns you don't want from the DataFrame
df_filtered = df[~df['Position'].str.contains('GK')]
df_filtered = df_filtered.drop(columns_to_exclude, axis=1)

# %%
df_filtered
# Out:
#                       Position Best Pos Best Role   CA  Wor  Vis  Thr  Tec  \
# 0              AM (RC), ST (C)   AM (R)        IF  195    7   20    2   20
# 1              AM (RL), ST (C)   ST (C)        CF  195   10   14    2   17
# 2              AM (RL), ST (C)   ST (C)        AF  181   10   13    1   17
# 4       M (L), AM (LC), ST (C)   AM (L)        IW  186   10   16    1   20
# 5                       ST (C)   ST (C)        AF  166   13   13    2   14
# ...                        ...      ...       ...  ...  ...  ...  ...  ...
# 144745                  ST (C)   ST (C)         P    3    3    1    4    6
# 144746                   M (C)    M (C)        CM    2    9    4    3    5
# 144747                  ST (C)   ST (C)         P    2    2    1    3    1
# 144748                   M (C)    M (C)        CM    1    8    7    2    8
# 144749                   M (C)    M (C)       BWM    1   10    2    3    3
#
# ...
